# %%
import pandas as pd
import numpy as np
from collections import Counter,defaultdict
import sys,re
sys.path.append('../')
from lib.visualization import * 
from lib.dictionaries.author_duplicates import * 
sermons_metadata = pd.read_csv("/Users/amycweng/DH/SERMONS_APP/db/data/sermons.csv",header=None)
sermons = list(sermons_metadata[0])
dates = list(sermons_metadata[8])
authors = list(sermons_metadata[4])
pubplace = list(sermons_metadata[6])

missing_sermons = pd.read_csv("/Users/amycweng/DH/SERMONS_APP/db/data/sermons_missing.csv",header=None)
sermons.extend(list(missing_sermons[0]))
dates.extend(list(missing_sermons[8]))
authors.extend(list(missing_sermons[4]))
pubplace.extend(list(missing_sermons[6]))
len(sermons)
# Out:
# 5729

# %% [markdown]
# ## Publication Places

# %%
import csv 
outputfolder = "/Users/amycweng/DH/SERMONS_APP/db/data"
new = []
for idx,tcpID in enumerate(sermons): 
    found = False
    place = pubplace[idx]
    place = re.sub("Imprinted at |Impkinted sic at at sic |Printed at |At |Jmprynted at |Imprynted at |Excusum |Newly imprinted at |Jmprinted at |Prynted at |Enprynted at |Imprentit at |Imprented at |Impri n ted at |Newly enprynted at | printed$|Printed in |Imprinted in ","",place)
    place = re.sub("London|Londini|Londres|Londo n|london|Londom|Londoon|londun|S l|Lonnon i e London|1574 London","London",place)
    place = re.sub("Oxon|Oxford Oxfordshire","Oxford",place)
    place = re.sub("Westmynstre|Westmestre","Westminster",place)
    place = re.sub("Cambridg e|Cambridge Cambridgeshire","Cambridge",place)
    place = re.sub("Boston Mass|Boston Massachusetts|Boston in N E|Boston in New England|Boston New England|Bostonachusetts","Boston",place)
    place = re.sub("Boston New England|Bostonachusetts","Boston",place)
    place = re.sub("Middelburgh|Middelburg|Middelborough","Middleborough",place)
    place = re.sub("Edenborough in Scotland","Edinburgh",place)
    if "Savoy" in place: 
        place = "London in the Savoy"
    new.append({0:tcpID, 
                1:place})
with open(f"{outputfolder}/pubplace.csv","w+") as outfile: 
    writer = csv.DictWriter(outfile, fieldnames=new[0].keys())
    writer.writerows(new)

# %% [markdown]
# ## Dates

# %%
def visualize(x,y,title,xlabel,ylabel,color):
    plt.figure(figsize = (15, 10))
    plt.bar(x,y,color=color)
    plt.title(title, fontsize=20)
    plt.xlabel(xlabel, fontsize=15)
    plt.xticks(np.arange(min(x), max(x)+1, 10.0), fontsize=12)
    plt.ylabel(ylabel, fontsize=15)
    plt.yticks(fontsize=10)
    plt.show()

# %%
x,y = [],[]
date_counts = Counter(dates)
for date in sorted(date_counts): 
    if "?" in date: continue
    if "-" in date: 
        date = date.split("-")[0]
    x.append(int(date))
    y.append(date_counts[date])
visualize(x,y,'Books of Sermons in EEBO-TCP','Year of Publication','Count of Sermons','grey')

# %%
print(Counter(dates).most_common(n=10))
# Out:
# [('1660', 141), ('1698', 126), ('1700', 115), ('1695', 114), ('1682', 108), ('1692', 106), ('1685', 106), ('1694', 106), ('1683', 99), ('1689', 98)]

# %%
posthumous = defaultdict(list)
within = defaultdict(list)
post_aut = []
within_aut = []
all_aut = []
aut_dup = {}
for k, v in duplicates.items(): 
    for item in v: 
        aut_dup[item] = k 

for idx, tcpID in enumerate(sermons): 
    date = dates[idx]
    aut = authors[idx].split("; ")
    if "?" in date: 
        date = date.split("-")[0]
    for author in aut:
        author = author.strip(" ").strip(".")
        if re.search(r'\w+[\)]{0,},',author):
            additional = re.findall(r'\d+(\.[\w+\-\,\s+\.]+)',author)
            if len(additional) > 0: 
                author = re.sub(additional[0], "",author)
        
        if author in aut_dup: 
            author = aut_dup[author]
        all_aut.append(author)

        if "England and Wales" in author or "House" in author: 
            within[date].append(tcpID)
            break
        elif author == "Anonymous": 
            break
        elif re.search(r"d. \d+",author): 
            yod = re.findall(r"d. (\d+)",author)[0]
            if date <= yod:
                within[date].append(tcpID)
                within_aut.append(tcpID)
        elif re.search(r'\d+[?]{0,1}-\d+[?]{0,1}',author): 
            years = re.findall('\d+',author)
            if date <= years[-1]: 
                within[date].append(tcpID)
                within_aut.append(author)
            else: 
                posthumous[date].append(tcpID)
                post_aut.append(author)

# %%
aut_tcpIDs = {}
from lib.dictionaries.author_duplicates import duplicates
dup_to_aut = {}
for k,v in duplicates.items(): 
    for aut in v: dup_to_aut[aut] = k

for idx, tcpID in enumerate(sermons): 
    date = dates[idx]
    aut = authors[idx].split("; ")
    if "?" in date: continue
    for author in aut:
        author = author.strip(" ").strip(".")
        if re.search(r'\w+[\)]{0,},',author):
            additional = re.findall(r'\d+(\.[\w+\-\,\s+\.]+)',author)
            if len(additional) > 0: 
                author = re.sub(additional[0], "",author)
        if author in dup_to_aut: 
            author = dup_to_aut[author]
        if author not in aut_tcpIDs: 
            aut_tcpIDs[author] = []
        aut_tcpIDs[author].append(tcpID)

# %%
new = []
for aut, tcpIDs in aut_tcpIDs.items(): 
    # if re.search(r'engraver|publisher|ed.',aut): continue 
    for tcpID in tcpIDs: 
        if {'author':aut,'tcpID':tcpID} not in new: 
            new.append({'author':aut,'tcpID':tcpID})

# %%
import csv
with open("/Users/amycweng/DH/SERMONS_APP/db/data/authors.csv","w+") as outfile: 
    writer = csv.DictWriter(outfile, fieldnames=['author','tcpID'])
    writer.writerows(new)

# %%
tcpIDs_aut = {}
for aut, tcpIDs in aut_tcpIDs.items(): 
    for t in tcpIDs: 
        if t not in tcpIDs_aut: tcpIDs_aut[t] = []
        tcpIDs_aut[t].append(aut)

# %%
len(tcpIDs_aut)
# Out:
# 5728

# %%
single_aut, multiple_aut = {},{}
for tcpID, aut in tcpIDs_aut.items(): 
    if len(aut) == 1: 
        aut = aut[0]
        if aut not in single_aut: 
            single_aut[aut] = []
        single_aut[aut].append(tcpID)
    else: 
        aut = "; ".join(aut)
        if aut not in multiple_aut: 
            multiple_aut[aut] = []
        multiple_aut[aut].append(tcpID)

# %%
len(single_aut), len(multiple_aut)
# Out:
# (2292, 587)

# %%
sum([len(v) for v in single_aut.values()]),sum([len(v) for v in multiple_aut.values()])
# Out:
# (5064, 664)

# %%
singles = [k for k,v in single_aut.items() if len(v) == 1]
len(singles)
# Out:
# 1431

# %%
prefix = [k[:2] for k in singles]
from collections import Counter 
Counter(prefix)
# Out:
# Counter({'Ba': 44,
#          'Ma': 39,
#          'Ha': 37,
#          'Br': 35,
#          'Ho': 31,
#          'Wi': 30,
#          'Ca': 29,
#          'Be': 29,
#          'St': 28,
#          'Co': 28,
#          'Wa': 27,
#          'Bu': 24,
#          'Hu': 23,
#          'Ro': 21,
#          'Go': 20,
#          'Pa': 20,
#          'Hi': 20,
#          'Wh': 19,
#          'La': 19,
#          'Pr': 19,
#          'Le': 18,
#          'Sh': 18,
#          'Cr': 17,
#          'Mo': 17,
#          'Ch': 17,
#          'Wo': 17,
#          'Do': 16,
#          'He': 16,
#          'Pe': 16,
#          'Fo': 14,
#          'Mi': 14,
#          'Bo': 14,
#          'J.': 13,
#          'Th': 13,
#          'Cl': 13,
#          'Gr': 13,
#          'Ja': 13,
#          'Gi': 13,
#          'Sa': 13,
#          'Jo': 12,
#          'Sp': 12,
#          'Re': 12,
#          'Po': 12,
#          'Da': 12,
#          'Sc': 12,
#          'Ra': 11,
#          'Je': 11,
#          'Sm': 11,
#          'Li': 10,
#          'Al': 10,
#          'Ga': 10,
#          'Ne': 10,
#          'R.': 10,
#          'An': 10,
#          'Pi': 9,
#          'De': 9,
#          'Si': 9,
#          'We': 9,
#          'Se': 9,
#          'Me': 9,
#          'Ki': 9,
#          'Fa': 9,
#          'Fe': 9,
#          'Lo': 8,
#          'El': 8,
#          'Tr': 8,
#          'T.': 8,
#          'Ta': 8,
#          'Bi': 8,
#          'Ri': 8,
#          'Fi': 8,
#          'Du': 7,
#          'Ke': 7,
#          'Ad': 7,
#          'Bl': 7,
#          'Ev': 7,
#          'Ph': 7,
#          'Gu': 6,
#          'Fu': 6,
#          'Lu': 6,
#          'Ni': 6,
#          'W.': 6,
#          'Ol': 6,
#          'No': 6,
#          'To': 6,
#          'Te': 6,
#          'Pu': 6,
#          'Ow': 5,
#          'Sw': 5,
#          'En': 5,
#          'Fr': 5,
#          'As': 5,
#          'Wy': 5,
#          'Ru': 4,
#          'Tu': 4,
#          'Ty': 4,
#          'Kn': 4,
#          'By': 4,
#          'Di': 4,
#          'Cu': 4,
#          'Sk': 4,
#          'At': 4,
#          'H.': 4,
#          'Dr': 4,
#          'In': 3,
#          'So': 3,
#          'Ge': 3,
#          'Am': 3,
#          'Wr': 3,
#          'Ed': 3,
#          'Ve': 3,
#          'Sy': 3,
#          'Mu': 3,
#          'Ea': 3,
#          'Em': 2,
#          'P.': 2,
#          'Ir': 2,
#          "D'": 2,
#          'Ny': 2,
#          'Ov': 2,
#          'Yo': 2,
#          'Os': 2,
#          'Ar': 2,
#          'Ti': 2,
#          'Tw': 2,
#          'I.': 2,
#          'Fy': 2,
#          'N.': 2,
#          'E.': 2,
#          'D.': 2,
#          'Or': 2,
#          'Oa': 2,
#          'Va': 2,
#          'Ox': 2,
#          'Fl': 2,
#          'Dy': 2,
#          'A.': 2,
#          'Cy': 1,
#          'Ye': 1,
#          'On': 1,
#          'L.': 1,
#          'Eb': 1,
#          'Od': 1,
#          'Ew': 1,
#          '[K': 1,
#          '[H': 1,
#          '[M': 1,
#          'Ey': 1,
#          'Ee': 1,
#          'U.': 1,
#          '[P': 1,
#          'Ud': 1,
#          'Of': 1,
#          'Ag': 1,
#          '[B': 1,
#          'Ai': 1,
#          'Su': 1,
#          'Ll': 1,
#          'Gl': 1,
#          'Na': 1,
#          'Ot': 1,
#          'Ok': 1,
#          'Qu': 1,
#          'Hy': 1,
#          '[L': 1,
#          'Eg': 1,
#          '[A': 1,
#          'Ac': 1,
#          '[G': 1,
#          'G.': 1,
#          'Ec': 1,
#          'Et': 1,
#          'Vo': 1,
#          'S.': 1,
#          'B.': 1,
#          'Pl': 1,
#          'Un': 1,
#          "L'": 1,
#          'Gy': 1})

# %%
print(Counter(all_aut).most_common(n=10))
# Out:
# [('Anonymous', 72), ('Tillotson, John, 1630-1694', 48), ('Burnet, Gilbert, 1643-1715', 38), ('Baxter, Richard, 1615-1691', 36), ('Stillingfleet, Edward, 1635-1699', 33), ('Reynolds, Edward, 1599-1676', 32), ('Calamy, Edmund, 1600-1666', 28), ('Hardy, Nathaniel, 1618-1670', 28), ('Donne, John, 1572-1631', 27), ('Smith, Henry, 1550?-1591', 27)]

# %%
print(Counter(post_aut).most_common(n=25))
# Out:
# [('Preston, John, 1587-1628', 26), ('Burroughs, Jeremiah, 1599-1646', 18), ('Smith, Henry, 1550?-1591', 15), ('Love, Christopher, 1618-1651', 12), ('Fenner, William, 1600-1640', 12), ('Calvin, Jean, 1509-1564', 12), ('Tillotson, John, 1630-1694', 12), ('Perkins, William, 1558-1602', 11), ('Manton, Thomas, 1620-1677', 10), ('Donne, John, 1572-1631', 9), ('Hopkins, Ezekiel, 1634-1690', 7), ('Luther, Martin, 1483-1546', 7), ('Gray, Andrew, 1633-1656', 7), ('Boyle, Robert, 1627-1691', 7), ('Stoughton, John, 1593-1639', 7), ('Andrewes, Lancelot, 1555-1626', 7), ('Sanderson, Robert, 1587-1663', 6), ('Dyke, Jeremiah, 1584-1639', 6), ('Rollock, Robert, 1555?-1599', 6), ('Playfere, Thomas, 1561?-1609', 6), ('Taylor, Thomas, 1576-1632', 5), ('Durham, James, 1622-1658', 5), ('Shepard, Thomas, 1605-1649', 5), ('Jewel, John, 1522-1571', 5), ('Barrow, Isaac, 1630-1677', 5)]

# %%
print(Counter(within_aut).most_common(n=25))
# Out:
# [('Burnet, Gilbert, 1643-1715', 38), ('Tillotson, John, 1630-1694', 36), ('Hardy, Nathaniel, 1618-1670', 27), ('Patrick, Simon, 1626-1707', 27), ('Williams, John, 1636?-1709', 24), ('Goodwin, Thomas, 1600-1680', 24), ('Marshall, Stephen, 1594?-1655', 24), ('Sherlock, William, 1641?-1707', 22), ('Sharp, John, 1645-1714', 22), ('Collinges, John, 1623-1690', 20), ('Mather, Cotton, 1663-1728', 20), ('Fuller, Thomas, 1608-1661', 20), ('Mather, Increase, 1639-1723', 19), ('Gataker, Thomas, 1574-1654', 19), ('Bates, William, 1625-1699', 18), ('Donne, John, 1572-1631', 18), ('Adams, Thomas, fl. 1612-1653', 18), ('Howe, John, 1630-1705', 17), ('Andrewes, Lancelot, 1555-1626', 17), ('Bridge, William, 1600?-1670', 17), ('Hall, Joseph, 1574-1656', 16), ('Shower, John, 1657-1715', 16), ('Caryl, Joseph, 1602-1673', 15), ('Willard, Samuel, 1640-1707', 15), ('Harris, Robert, 1581-1658', 15)]

# %%
x,y = [],[]
date_counts = {date: len(tcpIDs) for date, tcpIDs in Counter(posthumous).items()}
for date in sorted(date_counts): 
    if "?" in date: continue
    if "-" in date: 
        date = date.split("-")[0]
    if int(date) > 1700: continue
    x.append(int(date))
    y.append(date_counts[date])
visualize(x,y,'Posthumous Publications Per Year','Sermons','Count','darkblue')

# %%
print(sorted(date_counts.items(),reverse=True, key=lambda x:x[1]))
# Out:
# [('1640', 16), ('1657', 14), ('1660', 13), ('1675', 13), ('1672', 12), ('1699', 12), ('1633', 11), ('1678', 11), ('1661', 11), ('1698', 11), ('1685', 10), ('1692', 10), ('1683', 10), ('1676', 9), ('1659', 9), ('1629', 9), ('1694', 9), ('1682', 9), ('1653', 8), ('1681', 8), ('1623', 8), ('1674', 8), ('1695', 8), ('1649', 7), ('1641', 7), ('1693', 7), ('1548', 7), ('1583', 7), ('1677', 7), ('1654', 7), ('1648', 7), ('1680', 6), ('1650', 6), ('1684', 6), ('1668', 6), ('1658', 6), ('1700', 6), ('1697', 6), ('1664', 6), ('1630', 6), ('1691', 5), ('1652', 5), ('1644', 5), ('1632', 5), ('1666', 5), ('1592', 5), ('1635', 5), ('1696', 5), ('1679', 5), ('1636', 5), ('1606', 5), ('1646', 4), ('1577', 4), ('1671', 4), ('1647', 4), ('1669', 4), ('1638', 4), ('1655', 4), ('1686', 4), ('1673', 4), ('1631', 4), ('1607', 4), ('1642', 4), ('1639', 4), ('1617', 3), ('1587', 3), ('1634', 3), ('1670', 3), ('1610', 3), ('1645', 3), ('1656', 3), ('1579', 3), ('1581', 3), ('1580', 3), ('1574', 3), ('1613', 3), ('1603', 3), ('1612', 2), ('1557', 2), ('1578', 2), ('1604', 2), ('1546', 2), ('1687', 2), ('1651', 2), ('1663', 2), ('1688', 2), ('1616', 2), ('1628', 2), ('1570', 2), ('1611', 2), ('1593', 2), ('1584', 2), ('1662', 2), ('1615', 2), ('1626', 2), ('1595', 2), ('1710', 1), ('1588', 1), ('1596', 1), ('1530', 1), ('1559', 1), ('1598', 1), ('1643', 1), ('1547', 1), ('1689', 1), ('1605', 1), ('1625', 1), ('1620', 1), ('1549', 1), ('1562', 1), ('1618', 1), ('1534', 1), ('1498', 1), ('1627', 1), ('1599', 1), ('1614', 1), ('1667', 1), ('1690', 1), ('1582', 1), ('1609', 1), ('1542', 1), ('1608', 1), ('1619', 1), ('1594', 1), ('1637', 1)]

# %%
x,y = [],[]
date_counts = {date: len(tcpIDs) for date, tcpIDs in Counter(within).items()}
for date in sorted(date_counts): 
    if "?" in date: continue
    if "-" in date: 
        date = date.split("-")[0]
    if int(date) > 1700: continue
    x.append(int(date))
    y.append(date_counts[date])
visualize(x,y,'Non-Posthumous Publications','Sermons','Count','darkblue')

# %%
print(sorted(date_counts.items(),reverse=True, key=lambda x:x[1]))
# Out:
# [('1660', 95), ('1695', 84), ('1698', 84), ('1682', 78), ('1700', 78), ('1643', 77), ('1689', 77), ('1694', 72), ('1683', 70), ('1684', 68), ('1697', 67), ('1644', 66), ('1696', 66), ('1642', 64), ('1691', 64), ('1699', 64), ('1685', 63), ('1690', 63), ('1692', 63), ('1661', 62), ('1645', 61), ('1641', 60), ('1646', 60), ('1693', 58), ('1679', 57), ('1648', 55), ('1659', 52), ('1681', 48), ('1680', 48), ('1657', 46), ('1647', 46), ('1678', 46), ('1686', 45), ('1670', 44), ('1676', 43), ('1658', 43), ('1656', 41), ('1663', 41), ('1654', 40), ('1662', 39), ('1652', 37), ('1625', 37), ('1626', 36), ('1655', 35), ('1653', 35), ('1673', 35), ('1649', 34), ('1675', 34), ('1674', 34), ('1620', 32), ('1623', 31), ('1615', 31), ('1616', 31), ('1687', 30), ('1671', 29), ('1669', 29), ('1624', 29), ('1613', 28), ('1688', 28), ('1637', 27), ('1640', 26), ('1618', 26), ('1609', 25), ('1622', 25), ('1610', 25), ('1606', 25), ('1651', 24), ('1629', 24), ('1614', 24), ('1677', 24), ('1638', 23), ('1621', 23), ('1650', 23), ('1628', 23), ('1612', 23), ('1607', 22), ('1630', 22), ('1672', 22), ('1666', 22), ('1617', 21), ('1668', 20), ('1619', 20), ('1627', 20), ('1632', 19), ('1667', 18), ('1664', 17), ('1639', 17), ('1665', 17), ('1591', 16), ('1633', 16), ('1608', 15), ('1636', 15), ('1597', 14), ('1550', 13), ('1602', 13), ('1586', 12), ('1611', 12), ('1588', 11), ('1604', 11), ('1548', 11), ('1635', 10), ('1631', 10), ('1603', 10), ('1587', 9), ('1583', 8), ('1582', 8), ('1581', 8), ('1599', 8), ('1605', 8), ('1578', 8), ('1569', 7), ('1589', 7), ('1579', 7), ('1553', 7), ('1584', 7), ('1580', 6), ('1590', 6), ('1593', 6), ('1634', 6), ('1549', 5), ('1546', 5), ('1600', 5), ('1595', 5), ('1592', 5), ('1598', 5), ('1551', 5), ('1574', 5), ('1577', 4), ('1538', 4), ('1560', 4), ('1555', 4), ('1601', 4), ('1566', 4), ('1571', 4), ('1556', 3), ('1596', 3), ('1526', 3), ('1561', 3), ('1570', 3), ('1536', 3), ('1537', 3), ('1544', 3), ('1575', 2), ('1594', 2), ('1585', 2), ('1573', 2), ('1572', 2), ('1533', 2), ('1622-1623', 1), ('1530', 1), ('1545', 1), ('1576', 1), ('1535', 1), ('1558', 1), ('1547', 1), ('1532', 1), ('1509', 1), ('1534', 1), ('1498', 1), ('1554', 1), ('1557', 1), ('1552', 1), ('1562', 1), ('1495', 1), ('1542', 1), ('1521', 1), ('1565', 1), ('1497', 1), ('1539', 1)]

# %%
sorted_dates = sorted(date_counts)
print(sorted_dates[0],sorted_dates[-1])
date_to_tcpID = {}
for idx, date in enumerate(dates):
    if date not in date_to_tcpID: 
        date_to_tcpID[date] = []
    date_to_tcpID[date].append(sermons[idx])
# Out:
# 1495 1700

# %%
x,y = [],[]
author_pubs = defaultdict(list)
for idx, author in enumerate(authors): 
    aut = author.split("; ")
    for a in aut: 
        a = a.strip(r"  ").strip(".")
        if re.search(r'\w+[\)]{0,},',a):
            additional = re.findall(r'\d+(\.[\w+\-\,\. ]+)',a)
            if len(additional) > 0: 
                a = re.sub(additional[0], "",a)
        author_pubs[a].append(dates[idx])

# %%
from lib.dictionaries.author_duplicates import duplicates
known_dups = {}
for k, v in duplicates.items(): 
    known_dups[k] = 0
    for item in v:  
        known_dups[item] = 0

# %%
prefixes = {}
for a in author_pubs: 
    if a in known_dups: continue
    prefix = a.split(" ")[:2]
    prefix = " ".join(prefix)
    if prefix not in prefixes: 
        prefixes[prefix] = []
    if a not in prefixes[prefix]: 
        prefixes[prefix].append(a)

for prefix, p_list in prefixes.items(): 
    if len(p_list) > 1: 
        print(f"'{prefix}': {p_list},")
# Out:
# 'Lover of': ['Lover of ale', 'Lover of peace and truth'],
# 'Sharp, John,': ['Sharp, John, of Froome, Somersetshire', 'Sharp, John, 1645-1714'],
# 'Williams, John,': ['Williams, John, minister', 'Williams, John, 1636?-1709', 'Williams, John, Master of Arts', 'Williams, John, 1582-1650', 'Williams, John, 1664-1729'],
# 'White, Thomas,': ['White, Thomas, 1628-1698', 'White, Thomas, ca. 1550-1624', 'White, Thomas, 1593-1676'],
# 'Hancock, John,': ['Hancock, John, fl. 1669-1705', 'Hancock, John, fl. 1638-1675'],
# 'Ross, Alexander,': ['Ross, Alexander, 1647?-1720', 'Ross, Alexander, 1591-1654'],
# 'Abbot, Robert,': ['Abbot, Robert, 1588?-1662?', 'Abbot, Robert, 1560-1618'],
# 'J. B.': ['J. B. (John Bulteel), d. 1669', 'J. B. (John Bird), b. 1584 or 5', 'J. B. (John Butler)', 'J. B. (James Bradshaw), 1636?-1702'],
# 'Du Moulin,': ['Du Moulin, Pierre, 1568-1658', 'Du Moulin, Peter, 1601-1684'],
# 'Gardiner, Samuel,': ['Gardiner, Samuel, b. 1563 or 4', 'Gardiner, Samuel, 1619 or 20-1686'],
# 'Crompton, William,': ['Crompton, William, 1633-1696', 'Crompton, William, 1599?-1642'],
# 'Moore, John,': ['Moore, John, 1595?-1657', 'Moore, John, d. 1619', 'Moore, John, 1646-1714', 'Moore, John, of Wechicombe, near Dunster, Somerset', 'Moore, John, b. 1621'],
# 'Taylor, Thomas,': ['Taylor, Thomas, 1576-1632', 'Taylor, Thomas, 1618-1682', 'Taylor, Thomas, 1669 or 70-1735'],
# 'Owen, John,': ['Owen, John, 1616-1683, attributed name', 'Owen, John, 1616-1683', 'Owen, John, chaplain to Lord Grey of Ruthin'],
# 'Harrison, Thomas,': ['Harrison, Thomas, 1606-1660, attributed name', 'Harrison, Thomas, fl. 1700', 'Harrison, Thomas, 1619-1682'],
# 'Bulkley, Edward,': ['Bulkley, Edward, d. 1696', 'Bulkley, Edward, d. 1621?'],
# 'Willis, Thomas,': ['Willis, Thomas, 1619 or 20-1692', 'Willis, Thomas, 1651 or 2-1701'],
# 'Watson, Thomas,': ['Watson, Thomas, d. 1686', 'Watson, Thomas, 1513-1584'],
# 'La Motte,': ['La Motte, François de', 'La Motte, John, 1570?-1655'],
# 'J. R.': ['J. R. (James Rossington), b. 1642 or 3', 'J. R. (John Richardson), 1647-1696'],
# 'Cartwright, Thomas,': ['Cartwright, Thomas, 1535-1603', 'Cartwright, Thomas, 1634-1689'],
# 'Otes, Samuel,': ['Otes, Samuel, d. 1683', 'Otes, Samuel, 1578 or 9-1658'],
# 'Hume, John,': ['Hume, John, minister of religion in Yorkshire', 'Hume, John, 1634 or 5-1692'],
# 'Lindsay, David,': ['Lindsay, David, d. 1641?', 'Lindsay, David, 1565?-1627'],
# 'Donne, John,': ['Donne, John, 1572-1631', 'Donne, John, 1604-1662'],
# 'Calamy, Edmund,': ['Calamy, Edmund, 1600-1666', 'Calamy, Edmund, 1671-1732'],
# 'England and': ['England and Wales. Sovereign (1660-1685 : Charles II)', 'England and Wales. Parliament. House of Lords', 'England and Wales. Army. Honourable Artillery Company of London', 'England and Wales. Sovereign (1625-1649 : Charles I)'],
# 'Vaughan, Henry,': ['Vaughan, Henry, Sir, 1587?-1659?', 'Vaughan, Henry, 1622-1695', 'Vaughan, Henry, 1617 or 18-1661'],
# 'Cragge, John,': ['Cragge, John, Gent', 'Cragge, John, M.A'],
# 'Harrison, William,': ['Harrison, William, 1534-1593', 'Harrison, William, d. 1625'],
# 'Dove, John,': ['Dove, John, 1560 or 61-1618', 'Dove, John,'],
# 'Day, John,': ['Day, John, 1574-1640?', 'Day, John, 1566-1628'],
# 'Goodwin, Thomas,': ['Goodwin, Thomas, 1600-1680', 'Goodwin, Thomas, d. 1658', 'Goodwin, Thomas, 1650?-1716?'],
# 'Harrington, James,': ['Harrington, James, Sir, 1607-1680', 'Harrington, James, 1664-1693'],
# 'Hughes, John,': ['Hughes, John, fl. 1622', 'Hughes, John, b. 1651?'],
# 'Jackson, Thomas,': ['Jackson, Thomas, 1579-1640', 'Jackson, Thomas, d. 1646'],
# 'Stoughton, William,': ['Stoughton, William, fl. 1584, attributed name', 'Stoughton, William, 1632-1701'],
# 'Smith, Henry,': ['Smith, Henry, 1550?-1591', 'Smith, Henry, d. 1702'],
# 'Cooper, Thomas,': ['Cooper, Thomas, 1517?-1594', 'Cooper, Thomas, fl. 1626'],
# 'Smith, John,': ['Smith, John, 1563-1616', 'Smith, John, 1618-1652'],
# 'Bagshaw, Edward,': ['Bagshaw, Edward, d. 1662', 'Bagshaw, Edward, 1629-1671'],
# 'Parsons, Robert,': ['Parsons, Robert, 1546-1610', 'Parsons, Robert, 1647-1714'],
# 'Palmer, Anthony,': ['Palmer, Anthony, fl. 1632', 'Palmer, Anthony, 1618?-1679'],
# 'R. A.': ['R. A. (Richard Alleine), 1611-1681', 'R. A. (Richard Allen)'],
# 'Wilson, John,': ['Wilson, John, of Breedon, Leicestershire', 'Wilson, John, minister of the Word', 'Wilson, John, ca. 1654-ca. 1719', 'Wilson, John, 1588-1667'],
# 'Johnson, Robert,': ['Johnson, Robert, d. 1670', 'Johnson, Robert, chaplain to the Bishop of Lincoln'],
# 'Hall, William,': ['Hall, William, d. 1662', 'Hall, William, d. 1718?'],
# 'Mather, Samuel,': ['Mather, Samuel, 1626-1671', 'Mather, Samuel, 1651-1728'],
# 'Harris, John,': ['Harris, John, 1667?-1719', 'Harris, John, preacher at St. Margarets Church in Westminster'],
# 'Pritchard, Thomas,': ['Pritchard, Thomas, d. 1692', 'Pritchard, Thomas, M.A'],
# 'Evans, John,': ['Evans, John, 17th cent', 'Evans, John, minister of Gods word'],
# 'T. S.,': ['T. S., fl. 1624', 'T. S., fl. 1606'],
# 'Atterbury, Lewis,': ['Atterbury, Lewis, 1656-1731', 'Atterbury, Lewis, d. 1693'],
# 'Smith, Samuel,': ['Smith, Samuel, 1588-1665', 'Smith, Samuel, 1620-1698'],
# 'Cole, Thomas,': ['Cole, Thomas, d. 1571', 'Cole, Thomas, 1627?-1697'],
# 'Cotton, John,': ['Cotton, John, 1658-1710', 'Cotton, John, 1584-1652'],
# 'Hodges, Thomas,': ['Hodges, Thomas, 1599 or 1600-1672', 'Hodges, Thomas, d. 1688'],
# 'Fairclough, Richard,': ['Fairclough, Richard, 1594-1677', 'Fairclough, Richard, 1621-1682'],
# 'Carpenter, Richard,': ['Carpenter, Richard, d. 1670?', 'Carpenter, Richard, 1575-1627'],
# 'Durham, William,': ['Durham, William, 1611-1684', 'Durham, William, d. 1686'],
# 'Eedes, Richard,': ['Eedes, Richard, d. 1686', 'Eedes, Richard, 1555-1604'],
# 'White, John,': ['White, John, 1575-1648', 'White, John, 1570-1615'],
# 'Wilkinson, Henry,': ['Wilkinson, Henry, 1610-1675', 'Wilkinson, Henry, 1616-1690'],
# 'Warren, John,': ['Warren, John, minister of Hatfield Broad Oak, Essex', 'Warren, John, Vicar of Great Clacton'],
# 'Price, William,': ['Price, William, d. 1666', 'Price, William, 1597-1646'],
# 'Shepard, Thomas,': ['Shepard, Thomas, 1605-1649', 'Shepard, Thomas, 1635-1677'],
# 'Sclater, William,': ['Sclater, William, 1609-1661', 'Sclater, William, d. 1690', 'Sclater, William, 1575-1626'],
# 'Parr, Richard,': ['Parr, Richard, 1617-1691', 'Parr, Richard, 1591 or 2-1644'],
# 'Powell, Thomas,': ['Powell, Thomas, 1608-1660', 'Powell, Thomas, b. 1579 or 80'],
# 'Swan, John,': ['Swan, John, d. 1671', 'Swan, John, student in divinity'],
# 'Grantham, Thomas,': ['Grantham, Thomas, d. 1664', 'Grantham, Thomas, 1634-1692'],
# 'Drant, Thomas,': ['Drant, Thomas, b. 1601 or 2', 'Drant, Thomas, d. 1578?'],
# 'Thomas, William,': ['Thomas, William, 1593-1667', 'Thomas, William, 1613-1689'],
# 'Smith, Benjamin,': ['Smith, Benjamin, fl. 1681', 'Smith, Benjamin, 1642 or 3-1714'],
# 'Wood, James,': ['Wood, James, minister of the Gospel', 'Wood, James, 1608-1664'],
# 'Williams, William,': ['Williams, William, Inferior Brother to the venerable and orthodox clergy', "Williams, William, Minister of St. Mary's in Haverford"],
# 'Whitby, Daniel,': ['Whitby, Daniel, 1638-1726', 'Whitby, Daniel, b. 1609 or 10'],
# 'Symons, Henry,': ['Symons, Henry, fl. 1657-1658', 'Symons, Henry, M.A'],
# 'Gee, Edward,': ['Gee, Edward, 1657-1730', 'Gee, Edward, 1565-1618'],
# 'Gilbert, John,': ['Gilbert, John, b. 1658 or 9', 'Gilbert, John, d. 1722'],
# 'I. K.,': ['I. K., Native of the same place, sometimes preacher of Gods word there', 'I. K., fl. 1607'],
# 'Horne, Thomas,': ['Horne, Thomas, 1610-1654', 'Horne, Thomas, 1627?-1688'],
# 'James, John,': ['James, John, b. 1649', 'James, John, d. 1661'],
# 'J. G.,': ['J. G., D.D', 'J. G., member of the Church of England'],
# 'Lee, Richard,': ['Lee, Richard, 1611-1684', 'Lee, Richard, d. 1650'],
# 'Moore, Thomas,': ['Moore, Thomas, Junior', 'Moore, Thomas, Senior'],
# 'Pearson, Richard,': ['Pearson, Richard, Chaplain to the Earl of Elgin', 'Pearson, Richard, d. 1734'],
# 'Minister of': ['Minister of the Church of England', 'Minister of the Gospel'],
# 'Horne, Robert,': ['Horne, Robert, 1519?-1580', 'Horne, Robert, 1565-1640'],
# 'Carter, John,': ['Carter, John, 1554-1635', 'Carter, John, d. 1655'],
# 'Wilson, Thomas,': ['Wilson, Thomas, 1563-1622', 'Wilson, Thomas, 17th cent', 'Wilson, Thomas, 1601-1653'],
# 'Browne, Thomas,': ['Browne, Thomas, 1604?-1673', 'Browne, Thomas, ca. 1535-1585'],
# 'Robinson, John,': ['Robinson, John, preacher', 'Robinson, John, 1575?-1625'],
# 'Gee, John,': ['Gee, John, d. 1631', 'Gee, John, 1596-1639'],
# 'Bell, William,': ['Bell, William, 1626-1683', 'Bell, William, 1606 or 7-1681'],
# 'Faireclough, Samuel,': ['Faireclough, Samuel, 1625?-1691', 'Faireclough, Samuel, 1594-1677'],
# 'Dunton, John,': ['Dunton, John, 1627 or 8-1676', 'Dunton, John, 1659-1733'],
# 'N. H.,': ['N. H., Minister of the Gospel. Funeral sermon', 'N. H., fl. 1633'],
# 'Smith, William,': ['Smith, William, b. 1615 or 16', 'Smith, William, D.D', 'Smith, William, 1555 or 6-1615'],
# 'West, Richard,': ['West, Richard, 1614-1690', 'West, Richard, 1671 or 2-1716'],
# 'Walker, George,': ['Walker, George, of Londonderry', 'Walker, George, 1581?-1651'],
# 'Preston, John,': ['Preston, John, minister of East Ogwell', 'Preston, John, b. 1598 or 9'],
# 'Smith, Thomas,': ['Smith, Thomas, 1638-1710', 'Smith, Thomas, 1623 or 4-1661'],
# 'Spencer, John,': ['Spencer, John, Groom', 'Spencer, John, d. 1680', 'Spencer, John, 1630-1693'],
# 'More, John,': ['More, John, d. 1592', 'More, John, fl. 1533'],
# 'Price, John,': ['Price, John, Master of arts', 'Price, John, 1625?-1691', 'Price, John, 1576-1645'],
# 'Johnson, John,': ['Johnson, John, minister of Methley', 'Johnson, John, M.A'],
# 'Jackson, William,': ['Jackson, William, 1636 or 7-1680', 'Jackson, William, lecturer at Whittington College'],
# 'King, William,': ['King, William, preacher of the word of God', 'King, William, 1650-1729'],
# 'Catholic Church.': ['Catholic Church. Pope (1316-1334 : John XXII)', 'Catholic Church. Pope (1559-1565 : Pius IV). Professio fidei Tridentina. English & Latin'],
# 'Rogers, John,': ['Rogers, John, of Chacombe', 'Rogers, John, b. 1647'],
# 'Ford, Thomas,': ['Ford, Thomas, 1598-1674', 'Ford, Thomas, d. 1656'],
# 'Hayward, John,': ['Hayward, John, D.D', 'Hayward, John, Sir, 1564?-1627'],

# %%
author_counts = {aut: len(pubs) for aut, pubs in author_pubs.items()}
for aut,freq in sorted(author_counts.items(), key = lambda x: x[1],reverse=True)[:10]: 
    print(freq, "\t", aut, "\t", Counter(author_pubs[aut]))
# Out:
# 72 	 Anonymous 	 Counter({'1663': 4, '1643': 3, '1687': 3, '1678': 3, '1644': 3, '1685': 3, '1660': 2, '1672': 2, '1645': 2, '1641': 2, '1688': 2, '1674': 2, '1585': 2, '1689': 2, '1698': 2, '1670': 2, '1683': 2, '1684': 2, '1650': 2, '1700': 2, '1611': 1, '1704': 1, '1699': 1, '1548': 1, '1673': 1, '1662': 1, '1542': 1, '1559': 1, '1671': 1, '1680': 1, '1607': 1, '1635': 1, '1667': 1, '1694': 1, '1676': 1, '1600-1699?': 1, '1664': 1, '1682': 1, '1648': 1, '1692': 1, '1691': 1, '1653': 1, '1677': 1, '1640': 1, '1603': 1})
# 48 	 Tillotson, John, 1630-1694 	 Counter({'1694': 5, '1700': 4, '1687': 3, '1695': 3, '1675': 3, '1693': 3, '1689': 3, '1690': 3, '1678': 2, '1698': 2, '1679': 2, '1692': 2, '1682': 2, '1676': 1, '1691': 1, '1664': 1, '1696': 1, '1680': 1, '1697': 1, '1685': 1, '1681': 1, '1699': 1, '1686': 1, '1683': 1})
# 38 	 Burnet, Gilbert, 1643-1715 	 Counter({'1689': 8, '1690': 5, '1681': 3, '1697': 3, '1691': 3, '1694': 3, '1675': 3, '1684': 2, '1698': 2, '1700': 1, '1680': 1, '1695': 1, '1692': 1, '1678': 1, '1682': 1})
# 37 	 Baxter, Richard, 1615-1691 	 Counter({'1660': 5, '1656': 5, '1662': 3, '1678': 2, '1672': 2, '1670': 2, '1691': 2, '1680': 2, '1654': 1, '1681': 1, '1655': 1, '1661': 1, '1685': 1, '1657': 1, '1682': 1, '1673': 1, '1677': 1, '1690': 1, '1683': 1, '1663': 1, '1658': 1, '1674': 1})
# 33 	 Stillingfleet, Edward, 1635-1699 	 Counter({'1700': 2, '1669': 2, '1692': 2, '1681': 2, '1674': 2, '1697': 2, '1694': 2, '1691': 2, '1690': 2, '1693': 1, '1673': 1, '1682': 1, '1698': 1, '1679': 1, '1675': 1, '1680': 1, '1684': 1, '1696': 1, '1685': 1, '1678': 1, '1688': 1, '1666': 1, '1689': 1, '1667': 1})
# 32 	 Reynolds, Edward, 1599-1676 	 Counter({'1659': 7, '1660': 5, '1658': 3, '1657': 2, '1663': 2, '1662': 2, '1655': 1, '1666': 1, '1668': 1, '1652': 1, '1669': 1, '1649': 1, '1636': 1, '1638': 1, '1678': 1, '1631': 1, '1632': 1})
# 28 	 Calamy, Edmund, 1600-1666 	 Counter({'1662': 7, '1663': 3, '1655': 3, '1654': 2, '1657': 2, '1658': 2, '1642': 2, '1651': 2, '1646': 1, '1645': 1, '1652': 1, '1643': 1, '1680': 1})
# 28 	 Hardy, Nathaniel, 1618-1670 	 Counter({'1653': 5, '1658': 4, '1656': 3, '1659': 3, '1661': 2, '1648': 2, '1649': 1, '1660': 1, '1655': 1, '1654': 1, '1668': 1, '1666': 1, '1647': 1, '1662': 1, '1695': 1})
# 27 	 Donne, John, 1572-1631 	 Counter({'1626': 7, '1625': 6, '1634': 2, '1640': 2, '1623': 2, '1624': 1, '1661': 1, '1638': 1, '1649': 1, '1622': 1, '1627': 1, '1632': 1, '1639': 1})
# 27 	 Smith, Henry, 1550?-1591 	 Counter({'1591': 10, '1592': 4, '1593': 2, '1595': 2, '1590': 2, '1610': 1, '1598': 1, '1607': 1, '1688': 1, '1599': 1, '1594': 1, '1637': 1})

# %%
prefixes = ['B','A0','A1','A2','A3','A4','A5','A6','A7','A8','A9']

# %%
def get_era(start,end):
    era = {k:[] for k in prefixes}
    for idx, date in enumerate(dates): 
        tcpID = sermons[idx]
        if "-" in date: 
            date = int(date.split("-")[0])
        date = int(date)
        if 'B' in tcpID: 
            prefix = 'B'
        else: 
            prefix = tcpID[:2]
        if start <= date <= end:
            era[prefix].append(tcpID)
    return era

# %%
preE = get_era(1400,1557)
E = get_era(1558,1602)
J = get_era(1603,1624)
C = get_era(1625,1641)
CW = get_era(1642,1649)
IR = get_era(1650,1659)
CII = get_era(1660,1684)
JII = get_era(1685,1688)
WM = get_era(1689,1702)

corpora = {"pre-Elizabeth":preE,"Elizabeth":E, "JamesI":J, "CharlesI":C,"CivilWar":CW,"Interregnum":IR,
        "CharlesII":CII, "JamesII":JII, "WilliamAndMary":WM}

for era, corpus in corpora.items(): 
    print(era, sum([len(_) for _ in corpus.values()]))
# Out:
# pre-Elizabeth 83
# Elizabeth 305
# JamesI 674
# CharlesI 543
# CivilWar 618
# Interregnum 561
# CharlesII 1498
# JamesII 256
# WilliamAndMary 1189

# %%
import json
with open('../assets/corpora.json','w+') as file: 
    json.dump(corpora,file)
